# %% [markdown]
# <a href="https://colab.research.google.com/github/Hambach-AA/Big-Data-Mining-Lab/blob/main/Lab_10_IABD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pylab
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as shc

# %%
df = pd.read_csv("dataset.csv")
df.head()
df.shape
# Out:
# (1000, 3)

# %%
df.isnull().sum()
# Out:
# x          0
# y          0
# cluster    0
# dtype: int64

# %%
X = df.iloc[:, 0:2]
y = df.iloc[:, 2]

# %%
plt.figure(figsize=(10, 7))
plt.title("Single linkage")
dend = shc.dendrogram(shc.linkage(X, method='single'))

# %%
plt.figure(figsize=(10, 7))
plt.title("Complete linkage")
dend = shc.dendrogram(shc.linkage(X, method='complete'))

# %%
plt.figure(figsize=(10, 7))
plt.title("Group average")
dend = shc.dendrogram(shc.linkage(X, method='average'))

# %%
plt.figure(figsize=(10, 7))
plt.title("Расстояние Уорда (Ward)")
dend = shc.dendrogram(shc.linkage(X, method='ward'))
