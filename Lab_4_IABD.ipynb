# %% [markdown]
# <a href="https://colab.research.google.com/github/Hambach-AA/Big-Data-Mining-Lab/blob/main/Lab_4_IABD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pylab
# import seaborn as sns
import numpy as np
# import warnings
from sklearn.model_selection import train_test_split
from sklearn import tree
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score

# %%
df = pd.read_csv("grades.csv")
df.head()
df.shape
# Out:
# (72, 9)

# %%
df.isnull().sum()
# Out:
# PUPIL_SEX        0
# PUPIL_CLASS      0
# TEACHER_RIGHT    0
# TEACHER_CHK      0
# TEACHER_QUEST    0
# TEACHER_CORR     0
# PUPIL_CORR       0
# PUPIL_STRIP      0
# GRADE            0
# dtype: int64

# %%
df['PUPIL_SEX'] = df['PUPIL_SEX'].replace(['M','F'],['0','1'])
df['PUPIL_CLASS'] = df['PUPIL_CLASS'].replace(['8A','8B'],['0','1'])

X = df[["PUPIL_SEX","PUPIL_CLASS","TEACHER_RIGHT", "TEACHER_CHK", "TEACHER_QUEST", "TEACHER_CORR", "PUPIL_CORR", "PUPIL_STRIP"]]
Y = df.GRADE

f1 = []
accur = []
precis = []
rec = []

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.4, train_size = 0.6)
dt_clf = tree.DecisionTreeClassifier(criterion = "gini")
dt_clf = dt_clf.fit(X_train, y_train)
y_pred = dt_clf.predict(X_test)
feature_names = ["PUPIL_SEX","PUPIL_CLASS","TEACHER_RIGHT", "TEACHER_CHK", "TEACHER_QUEST", "TEACHER_CORR", "PUPIL_CORR", "PUPIL_STRIP"]
fig = plt.figure(figsize=(25,20))
plot = tree.plot_tree(dt_clf, 
                max_depth=15,
                feature_names=feature_names,
                filled=True)
y_test.shape
f1.append(float(f1_score(y_test, y_pred,average='macro')))
accur.append(float(accuracy_score(y_test, y_pred)))
precis.append(float(precision_score(y_test, y_pred, average='macro')))
rec.append(float(recall_score(y_test, y_pred, average='macro')))
print("F-мера : " , f1_score(y_test, y_pred,average='macro'))
print("Аккуратность : " , accuracy_score(y_test, y_pred))
print("Точность : " , precision_score(y_test, y_pred, average='macro'))
print("Полнота : " , recall_score(y_test, y_pred,average='macro'))
# Out:
# F-мера :  0.5735119047619048
# Аккуратность :  0.6206896551724138
# Точность :  0.5821428571428571
# Полнота :  0.6020833333333333

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.35, train_size = 0.65)
dt_clf = tree.DecisionTreeClassifier(criterion = "gini")
dt_clf = dt_clf.fit(X_train, y_train)
y_pred = dt_clf.predict(X_test)
fig = plt.figure(figsize=(25,20))
plot = tree.plot_tree(dt_clf, 
                max_depth=15,
               feature_names=feature_names,
               filled=True)
y_test.shape
f1.append(float(f1_score(y_test, y_pred,average='macro')))
accur.append(float(accuracy_score(y_test, y_pred)))
precis.append(float(precision_score(y_test, y_pred, average='macro')))
rec.append(float(recall_score(y_test, y_pred, average='macro')))
print("F-мера : " , f1_score(y_test, y_pred,average='macro'))
print("Аккуратность : " , accuracy_score(y_test, y_pred))
print("Точность : " , precision_score(y_test, y_pred, average='macro'))
print("Полнота : " , recall_score(y_test, y_pred,average='macro'))
# Out:
# F-мера :  0.6129785247432307
# Аккуратность :  0.6538461538461539
# Точность :  0.625
# Полнота :  0.6666666666666667

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.30, train_size = 0.70)
dt_clf = tree.DecisionTreeClassifier(criterion = "gini")
dt_clf = dt_clf.fit(X_train, y_train)
y_pred = dt_clf.predict(X_test)
fig = plt.figure(figsize=(25,20))
plot = tree.plot_tree(dt_clf, 
                max_depth=15,
               feature_names=feature_names,
               filled=True)
y_test.shape
f1.append(float(f1_score(y_test, y_pred,average='macro')))
accur.append(float(accuracy_score(y_test, y_pred)))
precis.append(float(precision_score(y_test, y_pred, average='macro')))
rec.append(float(recall_score(y_test, y_pred, average='macro')))
print("F-мера : " , f1_score(y_test, y_pred,average='macro'))
print("Аккуратность : " , accuracy_score(y_test, y_pred))
print("Точность : " , precision_score(y_test, y_pred, average='macro'))
print("Полнота : " , recall_score(y_test, y_pred,average='macro'))
# Out:
# F-мера :  0.6418650793650794
# Аккуратность :  0.6818181818181818
# Точность :  0.7
# Полнота :  0.6401515151515151

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.25, train_size = 0.75)
dt_clf = tree.DecisionTreeClassifier(criterion = "gini")
dt_clf = dt_clf.fit(X_train, y_train)
y_pred = dt_clf.predict(X_test)
fig = plt.figure(figsize=(25,20))
plot = tree.plot_tree(dt_clf, 
                max_depth=15,
               feature_names=feature_names,
               filled=True)
y_test.shape
f1.append(float(f1_score(y_test, y_pred,average='macro')))
accur.append(float(accuracy_score(y_test, y_pred)))
precis.append(float(precision_score(y_test, y_pred, average='macro')))
rec.append(float(recall_score(y_test, y_pred, average='macro')))
print("F-мера : " , f1_score(y_test, y_pred,average='macro'))
print("Аккуратность : " , accuracy_score(y_test, y_pred))
print("Точность : " , precision_score(y_test, y_pred, average='macro'))
print("Полнота : " , recall_score(y_test, y_pred,average='macro'))
# Out:
# F-мера :  0.7063492063492064
# Аккуратность :  0.7222222222222222
# Точность :  0.6833333333333333
# Полнота :  0.78125

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.20, train_size = 0.80)
dt_clf = tree.DecisionTreeClassifier(criterion = "gini")
dt_clf = dt_clf.fit(X_train, y_train)
y_pred = dt_clf.predict(X_test)
fig = plt.figure(figsize=(25,20))
plot = tree.plot_tree(dt_clf, 
                max_depth=15,
               feature_names=feature_names,
               filled=True)
y_test.shape
f1.append(float(f1_score(y_test, y_pred,average='macro')))
accur.append(float(accuracy_score(y_test, y_pred)))
precis.append(float(precision_score(y_test, y_pred, average='macro')))
rec.append(float(recall_score(y_test, y_pred, average='macro')))
print("F-мера : " , f1_score(y_test, y_pred,average='macro'))
print("Аккуратность : " , accuracy_score(y_test, y_pred))
print("Точность : " , precision_score(y_test, y_pred, average='macro'))
print("Полнота : " , recall_score(y_test, y_pred,average='macro'))
# Out:
# F-мера :  0.6558823529411765
# Аккуратность :  0.7333333333333333
# Точность :  0.625
# Полнота :  0.8

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.15, train_size = 0.85)
dt_clf = tree.DecisionTreeClassifier(criterion = "gini")
dt_clf = dt_clf.fit(X_train, y_train)
y_pred = dt_clf.predict(X_test)
fig = plt.figure(figsize=(25,20))
plot = tree.plot_tree(dt_clf, 
                max_depth=15,
               feature_names=feature_names,
               filled=True)
y_test.shape
f1.append(float(f1_score(y_test, y_pred,average='macro')))
accur.append(float(accuracy_score(y_test, y_pred)))
precis.append(float(precision_score(y_test, y_pred, average='macro')))
rec.append(float(recall_score(y_test, y_pred, average='macro')))
print("F-мера : " , f1_score(y_test, y_pred,average='macro'))
print("Аккуратность : " , accuracy_score(y_test, y_pred))
print("Точность : " , precision_score(y_test, y_pred, average='macro'))
print("Полнота : " , recall_score(y_test, y_pred,average='macro'))
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# F-мера :  0.55
# Аккуратность :  0.7272727272727273
# Точность :  0.5333333333333333
# Полнота :  0.575

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.1, train_size = 0.9)
dt_clf = tree.DecisionTreeClassifier(criterion = "gini")
dt_clf = dt_clf.fit(X_train, y_train)
y_pred = dt_clf.predict(X_test)
fig = plt.figure(figsize=(25,20))
plot = tree.plot_tree(dt_clf, 
                max_depth=15,
               feature_names=feature_names,
               filled=True)
y_test.shape
f1.append(float(f1_score(y_test, y_pred,average='macro')))
accur.append(float(accuracy_score(y_test, y_pred)))
precis.append(float(precision_score(y_test, y_pred, average='macro')))
rec.append(float(recall_score(y_test, y_pred, average='macro')))
print("F-мера : " , f1_score(y_test, y_pred,average='macro'))
print("Аккуратность : " , accuracy_score(y_test, y_pred))
print("Точность : " , precision_score(y_test, y_pred, average='macro'))
print("Полнота : " , recall_score(y_test, y_pred,average='macro'))
# Out:
# F-мера :  0.6000000000000001
# Аккуратность :  0.75
# Точность :  0.6
# Полнота :  0.6

# %%
names = ["60/40", "65/35","70/30", "75/25", "80/20", "85/15", "90/10"]

pylab.figure(figsize=(10, 10))

pylab.subplot (2, 2, 1)

pylab.bar(names, f1)
pylab.xlabel("Соотношение мощностей О/Т выборок")
pylab.ylabel("F-мера")

pylab.subplot (2, 2, 2)

pylab.bar(names, accur)
pylab.xlabel("Соотношение мощностей О/Т выборок")
pylab.ylabel("Аккуратность")

pylab.subplot (2, 2, 3)

pylab.bar(names, precis)
pylab.xlabel("Соотношение мощностей О/Т выборок")
pylab.ylabel("Точность")

pylab.subplot (2, 2, 4)

pylab.bar(names, rec)
pylab.xlabel("Соотношение мощностей О/Т выборок")
pylab.ylabel("Полнота")

pylab.show()
