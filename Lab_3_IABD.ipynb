# %% [markdown]
# <a href="https://colab.research.google.com/github/Hambach-AA/Big-Data-Mining-Lab/blob/main/Lab_3_IABD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pylab
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score
from sklearn.naive_bayes import GaussianNB

# %%
df = pd.read_csv("grades.csv")
df.head()
df.shape
# Out:
# (72, 9)

# %%
df.isnull().sum()
# Out:
# PUPIL_SEX        0
# PUPIL_CLASS      0
# TEACHER_RIGHT    0
# TEACHER_CHK      0
# TEACHER_QUEST    0
# TEACHER_CORR     0
# PUPIL_CORR       0
# PUPIL_STRIP      0
# GRADE            0
# dtype: int64

# %%
df['PUPIL_SEX'] = df['PUPIL_SEX'].replace(['M','F'],['0','1'])
df['PUPIL_CLASS'] = df['PUPIL_CLASS'].replace(['8A','8B'],['0','1'])

X = df[["PUPIL_SEX","PUPIL_CLASS","TEACHER_RIGHT", "TEACHER_CHK", "TEACHER_QUEST", "TEACHER_CORR", "PUPIL_CORR", "PUPIL_STRIP"]]
Y = df.GRADE

f1 = []
accur = []
precis = []
rec = []

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.4, train_size = 0.6)

clf = GaussianNB()
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

f1.append(float(f1_score(y_test, y_pred,average='macro')))
accur.append(float(accuracy_score(y_test, y_pred)))
precis.append(float(precision_score(y_test, y_pred, average='macro')))
rec.append(float(recall_score(y_test, y_pred, average='macro')))

print("F-мера : " , f1_score(y_test, y_pred,average='macro'))
print("Аккуратность : " , accuracy_score(y_test, y_pred))
print("Точность : " , precision_score(y_test, y_pred, average='macro'))
print("Полнота : " , recall_score(y_test, y_pred,average='macro'))

plt.plot([i for i in range(len(y_pred))], y_test, '-', [i for i in range(len(y_pred))], y_pred, '--')
# Out:
# F-мера :  0.5087912087912088
# Аккуратность :  0.5172413793103449
# Точность :  0.5513392857142857
# Полнота :  0.5419642857142857
# [<matplotlib.lines.Line2D at 0x7fadb34bd880>,
#  <matplotlib.lines.Line2D at 0x7fadb34bd9a0>]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.35, train_size = 0.65)

clf = GaussianNB()
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

f1.append(float(f1_score(y_test, y_pred,average='macro')))
accur.append(float(accuracy_score(y_test, y_pred)))
precis.append(float(precision_score(y_test, y_pred, average='macro')))
rec.append(float(recall_score(y_test, y_pred, average='macro')))

print("F-мера : " , f1_score(y_test, y_pred,average='macro'))
print("Аккуратность : " , accuracy_score(y_test, y_pred))
print("Точность : " , precision_score(y_test, y_pred, average='macro'))
print("Полнота : " , recall_score(y_test, y_pred,average='macro'))

plt.plot([i for i in range(len(y_pred))], y_test, '-', [i for i in range(len(y_pred))], y_pred, '--')
# Out:
# F-мера :  0.5352474323062558
# Аккуратность :  0.5769230769230769
# Точность :  0.5604166666666667
# Полнота :  0.5291666666666666
# [<matplotlib.lines.Line2D at 0x7fadb332ba90>,
#  <matplotlib.lines.Line2D at 0x7fadb332bbb0>]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, train_size = 0.70)

clf = GaussianNB()
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

f1.append(float(f1_score(y_test, y_pred,average='macro')))
accur.append(float(accuracy_score(y_test, y_pred)))
precis.append(float(precision_score(y_test, y_pred, average='macro')))
rec.append(float(recall_score(y_test, y_pred, average='macro')))

print("F-мера : " , f1_score(y_test, y_pred,average='macro'))
print("Аккуратность : " , accuracy_score(y_test, y_pred))
print("Точность : " , precision_score(y_test, y_pred, average='macro'))
print("Полнота : " , recall_score(y_test, y_pred,average='macro'))

plt.plot([i for i in range(len(y_pred))], y_test, '-', [i for i in range(len(y_pred))], y_pred, '--')
# Out:
# F-мера :  0.4201680672268907
# Аккуратность :  0.45454545454545453
# Точность :  0.5125
# Полнота :  0.42083333333333334
# [<matplotlib.lines.Line2D at 0x7fadb352cd30>,
#  <matplotlib.lines.Line2D at 0x7fadb352ce50>]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.25, train_size = 0.75)

clf = GaussianNB()
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

f1.append(float(f1_score(y_test, y_pred,average='macro')))
accur.append(float(accuracy_score(y_test, y_pred)))
precis.append(float(precision_score(y_test, y_pred, average='macro')))
rec.append(float(recall_score(y_test, y_pred, average='macro')))

print("F-мера : " , f1_score(y_test, y_pred,average='macro'))
print("Аккуратность : " , accuracy_score(y_test, y_pred))
print("Точность : " , precision_score(y_test, y_pred, average='macro'))
print("Полнота : " , recall_score(y_test, y_pred,average='macro'))

plt.plot([i for i in range(len(y_pred))], y_test, '-', [i for i in range(len(y_pred))], y_pred, '--')
# Out:
# F-мера :  0.4419642857142857
# Аккуратность :  0.5
# Точность :  0.4910714285714286
# Полнота :  0.4097222222222222
# [<matplotlib.lines.Line2D at 0x7fadb3926730>,
#  <matplotlib.lines.Line2D at 0x7fadb39266a0>]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, train_size = 0.80)

clf = GaussianNB()
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

f1.append(float(f1_score(y_test, y_pred,average='macro')))
accur.append(float(accuracy_score(y_test, y_pred)))
precis.append(float(precision_score(y_test, y_pred, average='macro')))
rec.append(float(recall_score(y_test, y_pred, average='macro')))

print("F-мера : " , f1_score(y_test, y_pred,average='macro'))
print("Аккуратность : " , accuracy_score(y_test, y_pred))
print("Точность : " , precision_score(y_test, y_pred, average='macro'))
print("Полнота : " , recall_score(y_test, y_pred,average='macro'))

plt.plot([i for i in range(len(y_pred))], y_test, '-', [i for i in range(len(y_pred))], y_pred, '--')
# Out:
# F-мера :  0.5505952380952381
# Аккуратность :  0.6
# Точность :  0.625
# Полнота :  0.5267857142857143
# [<matplotlib.lines.Line2D at 0x7fadb343eca0>,
#  <matplotlib.lines.Line2D at 0x7fadb343e790>]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.15, train_size = 0.85)

clf = GaussianNB()
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

f1.append(float(f1_score(y_test, y_pred,average='macro')))
accur.append(float(accuracy_score(y_test, y_pred)))
precis.append(float(precision_score(y_test, y_pred, average='macro')))
rec.append(float(recall_score(y_test, y_pred, average='macro')))

print("F-мера : " , f1_score(y_test, y_pred,average='macro'))
print("Аккуратность : " , accuracy_score(y_test, y_pred))
print("Точность : " , precision_score(y_test, y_pred, average='macro'))
print("Полнота : " , recall_score(y_test, y_pred,average='macro'))

plt.plot([i for i in range(len(y_pred))], y_test, '-', [i for i in range(len(y_pred))], y_pred, '--')
# Out:
# F-мера :  0.44047619047619047
# Аккуратность :  0.5454545454545454
# Точность :  0.41666666666666663
# Полнота :  0.5
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [<matplotlib.lines.Line2D at 0x7fadb3a4a3a0>,
#  <matplotlib.lines.Line2D at 0x7fadb3a4a670>]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.1, train_size = 0.90)

clf = GaussianNB()
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

f1.append(float(f1_score(y_test, y_pred,average='macro')))
accur.append(float(accuracy_score(y_test, y_pred)))
precis.append(float(precision_score(y_test, y_pred, average='macro')))
rec.append(float(recall_score(y_test, y_pred, average='macro')))

print("F-мера : " , f1_score(y_test, y_pred,average='macro'))
print("Аккуратность : " , accuracy_score(y_test, y_pred))
print("Точность : " , precision_score(y_test, y_pred, average='macro'))
print("Полнота : " , recall_score(y_test, y_pred,average='macro'))

plt.plot([i for i in range(len(y_pred))], y_test, '-', [i for i in range(len(y_pred))], y_pred, '--')
# Out:
# F-мера :  0.45
# Аккуратность :  0.625
# Точность :  0.5
# Полнота :  0.41666666666666663
# [<matplotlib.lines.Line2D at 0x7fadb3b9eac0>,
#  <matplotlib.lines.Line2D at 0x7fadb3b9e190>]

# %%
names = ["60/40", "65/35","70/30", "75/25", "80/20", "85/15", "90/10"]

pylab.figure(figsize=(10, 10))

pylab.subplot (2, 2, 1)

pylab.bar(names, f1)
pylab.xlabel("Соотношение мощностей О/Т выборок")
pylab.ylabel("F-мера")

pylab.subplot (2, 2, 2)

pylab.bar(names, accur)
pylab.xlabel("Соотношение мощностей О/Т выборок")
pylab.ylabel("Аккуратность")

pylab.subplot (2, 2, 3)

pylab.bar(names, precis)
pylab.xlabel("Соотношение мощностей О/Т выборок")
pylab.ylabel("Точность")

pylab.subplot (2, 2, 4)

pylab.bar(names, rec)
pylab.xlabel("Соотношение мощностей О/Т выборок")
pylab.ylabel("Полнота")

pylab.show()
